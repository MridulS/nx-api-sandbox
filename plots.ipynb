# %%
from timing import timeout

# %%
# Sparse Graph with density 0.05
total_nodes = 10_000
jumps = 500
p = 0.05
timeout(p, total_nodes, jumps)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [03:12<00:00,  9.64s/it]

# %%
# Graph with density 0.2
p = 0.2
timeout(p, total_nodes, jumps)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [10:22<00:00, 31.11s/it]

# %%
# Dense Graph with density 0.8
p = 0.8
total_nodes = 6_000
jumps = 1_000
timeout(p, total_nodes, jumps)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [02:43<00:00, 32.74s/it]

# %%
import grblas as gb
import networkx as nx
G = nx.erdos_renyi_graph(11, 0.2)
M = gb.io.from_networkx(G, nodelist=list(G), dtype=float)
from nx_api import pagerank

# %%
pagerank(G)
# Out:
# {0: 0.014778325123152712,
#  1: 0.09964637512236146,
#  2: 0.05896251311893183,
#  3: 0.1378814574242636,
#  4: 0.09295043490864202,
#  5: 0.09334846700617921,
#  6: 0.13587650797813888,
#  7: 0.10396319987951849,
#  8: 0.10910145609218716,
#  9: 0.0923437892473267,
#  10: 0.061147474099297994}

# %%
pagerank(M)
# Out:
# {0: 0.014778325123152712,
#  1: 0.09964637512236148,
#  2: 0.05896251311893183,
#  3: 0.1378814574242636,
#  4: 0.09295043490864202,
#  5: 0.09334846700617921,
#  6: 0.13587650797813888,
#  7: 0.10396319987951849,
#  8: 0.10910145609218716,
#  9: 0.0923437892473267,
#  10: 0.061147474099297994}
